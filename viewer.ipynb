# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('flight_api_test_results.csv')

# %%
df
# Out:
#     success  response_time  status_code                  route        date  \
# 0     False       3.674609          200    Shanghai -> Beijing  2025-07-20
# 1     False       3.160995          200    Shanghai -> Beijing  2025-07-20
# 2     False       3.926758          200    Beijing -> Shanghai  2025-07-20
# 3     False       4.184936          200    Beijing -> Shanghai  2025-07-20
# 4     False       3.002865          200    Shenzhen -> Beijing  2025-07-20
# 5     False       3.720231          200    Shenzhen -> Beijing  2025-07-20
# 6     False       2.852001          200    Hangzhou -> Beijing  2025-07-20
# 7     False       3.206437          200    Hangzhou -> Beijing  2025-07-20
# 8     False       3.232484          200    Beijing -> Shenzhen  2025-07-20
# 9     False       4.233063          200    Beijing -> Shenzhen  2025-07-20
# 10    False       2.600498          200    Beijing -> Hangzhou  2025-07-20
# ...

# %%
df_filtered = df[df["flightCount"] > 0]

# Calculate average response_time for each endpoint type
avg_response_time = df_filtered.groupby("endpoint")["response_time"].mean()
avg_response_time
# Out:
# endpoint
# new    3.168758
# old    2.946645
# Name: response_time, dtype: float64
